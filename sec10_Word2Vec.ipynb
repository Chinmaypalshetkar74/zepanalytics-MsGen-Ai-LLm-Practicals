# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %% [markdown]
# Word2Vec is a machine learning model by google that turns words into numbers—specifically, vectors—so computers can understand their meanings and relationships.
# - 🧠 It captures semantic similarity: words like king and queen end up close together.
# - ⚙️ Uses two methods: CBOW (predicts a word from context) and Skip-Gram (predicts context from a word).
# - 🚀 Helps in tasks like sentiment analysis, search engines, and chatbots.
# Let me know if you want to try it out with your own dataset or explore visualizations!

# %%
# !pip install gensim

# %%
from

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Step 1: Install gensim
# !pip install gensim

# Step 2: Import the API
import gensim.downloader as api

# Step 3: List available pre-trained models
api.info()  # shows all available models

# Step 4: Load a pre-trained model (example: Word2Vec trained on Google News)
model = api.load("word2vec-google-news-300")

# Step 5: Test the model
print(model.most_similar("king"))
# Out:
# ...
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# [('kings', 0.7138045430183411), ('queen', 0.6510956883430481), ('monarch', 0.6413194537162781), ('crown_prince', 0.6204220056533813), ('prince', 0.6159993410110474), ('sultan', 0.5864824056625366), ('ruler', 0.5797567367553711), ('princes', 0.5646552443504333), ('Prince_Paras', 0.5432944297790527), ('throne', 0.5422105193138123)]

# %%
model['man']
# Out:
# array([ 0.32617188,  0.13085938,  0.03466797, -0.08300781,  0.08984375,
#        -0.04125977, -0.19824219,  0.00689697,  0.14355469,  0.0019455 ,
#         0.02880859, -0.25      , -0.08398438, -0.15136719, -0.10205078,
#         0.04077148, -0.09765625,  0.05932617,  0.02978516, -0.10058594,
#        -0.13085938,  0.001297  ,  0.02612305, -0.27148438,  0.06396484,
#        -0.19140625, -0.078125  ,  0.25976562,  0.375     , -0.04541016,
#         0.16210938,  0.13671875, -0.06396484, -0.02062988, -0.09667969,
#         0.25390625,  0.24804688, -0.12695312,  0.07177734,  0.3203125 ,
#         0.03149414, -0.03857422,  0.21191406, -0.00811768,  0.22265625,
#        -0.13476562, -0.07617188,  0.01049805, -0.05175781,  0.03808594,
#        -0.13378906,  0.125     ,  0.0559082 , -0.18261719,  0.08154297,
#        -0.08447266, -0.07763672, -0.04345703,  0.08105469, -0.01092529,
#         0.17480469,  0.30664062, -0.04321289, -0.01416016,  0.09082031,
# ...

# %%
model['man'].shape
# Out:
# (300,)

# %%
model['glass']
# Out:
# array([-0.22363281,  0.12402344, -0.09130859,  0.03808594,  0.04833984,
#         0.25390625,  0.4296875 , -0.15039062,  0.28515625,  0.49023438,
#        -0.20507812, -0.30664062,  0.11669922, -0.29882812, -0.13476562,
#        -0.09570312, -0.12109375, -0.08105469,  0.02380371, -0.07421875,
#         0.15722656,  0.04614258,  0.12695312, -0.08300781, -0.140625  ,
#         0.29882812,  0.05688477,  0.24121094, -0.07763672, -0.03015137,
#        -0.09960938, -0.08203125, -0.08837891, -0.07177734,  0.11621094,
#        -0.14355469, -0.08837891,  0.203125  , -0.17382812,  0.10595703,
#         0.01953125,  0.0145874 ,  0.10839844, -0.1484375 ,  0.13183594,
#         0.0534668 , -0.10546875, -0.07861328,  0.046875  , -0.06494141,
#        -0.11230469,  0.18261719, -0.10107422, -0.06542969, -0.14550781,
#         0.05004883,  0.03759766,  0.10351562, -0.02526855, -0.07958984,
#        -0.22753906, -0.07861328, -0.09570312, -0.3125    , -0.16699219,
# ...

# %%
print(model.most_similar("queen"))
# Out:
# [('queens', 0.739944338798523), ('princess', 0.7070532441139221), ('king', 0.6510956883430481), ('monarch', 0.6383602023124695), ('very_pampered_McElhatton', 0.6357026696205139), ('Queen', 0.6163407564163208), ('NYC_anglophiles_aflutter', 0.6060680150985718), ('Queen_Consort', 0.5923796892166138), ('princesses', 0.5908074975013733), ('royal', 0.5637185573577881)]

# %%
model.most_similar("boy")
# Out:
# [('girl', 0.8543272018432617),
#  ('teenager', 0.7606689929962158),
#  ('toddler', 0.7043969035148621),
#  ('teenage_girl', 0.6851482391357422),
#  ('man', 0.6824870109558105),
#  ('teen_ager', 0.6499968767166138),
#  ('son', 0.6337764263153076),
#  ('kid', 0.63228440284729),
#  ('youngster', 0.618381679058075),
#  ('stepfather', 0.5989423394203186)]

# %%
model.most_similar("cricket")
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.similarity('man','women')
# Out:
# np.float32(0.2883053)

# %%
model.similarity('king','women')
# Out:
# np.float32(0.028709669)

# %%
model.similarity('king','man')
# Out:
# np.float32(0.22942673)

# %%
model.similarity('king','lion')
# Out:
# np.float32(0.24740149)

# %%
model.similarity('java','javascript')
# Out:
# np.float32(0.33437246)

# %%
model.similarity('man','boy')
# Out:
# np.float32(0.68248713)

# %%
model.most_similar("python")
# Out:
# [('pythons', 0.66883784532547),
#  ('Burmese_python', 0.6680365800857544),
#  ('snake', 0.6606292724609375),
#  ('crocodile', 0.6591362953186035),
#  ('boa_constrictor', 0.6443520188331604),
#  ('alligator', 0.6421656608581543),
#  ('reptile', 0.6387745141983032),
#  ('albino_python', 0.6158880591392517),
#  ('croc', 0.6083583831787109),
#  ('lizard', 0.6013416647911072)]

# %%
model.doesnt_match(['Java','Python','Elephant'])
# Out:
# 'Elephant'

# %%
vec = model['king'] - model['man'] + model['woman']
model.most_similar([vec])
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('Queen_Consort', 0.5344247817993164),
#  ('queens', 0.5289887189865112)]

# %% [markdown]
# **Word2Vec 50Features**

# %%
model['king'].shape
# Out:
# (300,)

# %%
#king queen women girl boy man water

# %%
model['king'][0:50]
# Out:
# array([ 0.12597656,  0.02978516,  0.00860596,  0.13964844, -0.02563477,
#        -0.03613281,  0.11181641, -0.19824219,  0.05126953,  0.36328125,
#        -0.2421875 , -0.30273438, -0.17773438, -0.02490234, -0.16796875,
#        -0.16992188,  0.03466797,  0.00521851,  0.04638672,  0.12890625,
#         0.13671875,  0.11279297,  0.05957031,  0.13671875,  0.10107422,
#        -0.17675781, -0.25195312,  0.05981445,  0.34179688, -0.03112793,
#         0.10449219,  0.06176758,  0.12451172,  0.40039062, -0.32226562,
#         0.08398438,  0.0390625 ,  0.00585938,  0.0703125 ,  0.17285156,
#         0.13867188, -0.23144531,  0.28320312,  0.14257812,  0.34179688,
#        -0.02392578, -0.10986328,  0.03320312, -0.0546875 ,  0.01531982],
#       dtype=float32)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#king queen women girl boy man water

words = ['king','queen','women','girl','boy','man','water']
embeddings = np.array([
     model['queen'][0:50],
     model['king'][0:50],
     model['women'][0:50],
     model['girl'][0:50],
     model['boy'][0:50],
     model['man'][0:50],
     model['water'][0:50]
                       ])

df= pd.DataFrame(embeddings,index=words)
df
# Out:
#              0         1         2         3         4         5         6   \
# king   0.005249 -0.143555 -0.069336  0.123535  0.131836 -0.088867 -0.071289
# queen  0.125977  0.029785  0.008606  0.139648 -0.025635 -0.036133  0.111816
# women -0.139648  0.164062  0.016113  0.107910  0.218750 -0.263672 -0.113281
# girl   0.138672  0.003738  0.064453 -0.076172  0.024780 -0.015381 -0.111816
# boy    0.235352  0.165039  0.093262 -0.128906  0.015991  0.036133 -0.116699
# man    0.326172  0.130859  0.034668 -0.083008  0.089844 -0.041260 -0.198242
# water -0.151367  0.136719  0.116699 -0.178711 -0.111816  0.007446 -0.002625
#
#              7         8         9   ...        40        41        42  \
# king  -0.216797 -0.197266  0.055664  ...  0.106934 -0.416016  0.269531
# queen -0.198242  0.051270  0.363281  ...  0.138672 -0.231445  0.283203
# women -0.119629 -0.066895  0.096191  ... -0.062988  0.099609  0.051758
# girl  -0.101562  0.046143  0.091797  ... -0.148438 -0.055908  0.253906
# ...

# %%
#create hasmap
plt.figure(figsize=(20,10))
sns.heatmap(df,annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#king queen women girl boy man water

words = ['king','queen','women','girl','boy','man','water']
embeddings = np.array([
     model['queen'][0:10],
     model['king'][0:10],
     model['women'][0:10],
     model['girl'][0:10],
     model['boy'][0:10],
     model['man'][0:10],
     model['water'][0:10]
                       ])

df1= pd.DataFrame(embeddings,index=words)
#create hasmap
plt.figure(figsize=(20,10))
sns.heatmap(df1,annot=True)
# Out:
# <Axes: >
